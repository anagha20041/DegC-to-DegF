# %% [markdown]
# <a href="https://colab.research.google.com/github/anagha20041/DegC-to-DegF/blob/main/CelsiusToFahrenheit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # formula

# %%
#t(f)=t(c)*9/5+32

#predict value of variable y based on variable x
#y=dependednt
#x=independent this is regression

# %% [markdown]
# # how ann learns

# %% [markdown]
# neurons have neuclus dendriotes axons hence human brain learn by creating connections among neurons
# ann are info processing models insprided by the human brain
#
# output=input * W1+Bias

# %% [markdown]
# #import libraries

# %%
# !pip install tensorflow

# %%
import tensorflow as tf
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #import datasets

# %%
temp_df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Celsius+to+Fahrenheit.csv')

# %%
temp_df.head(5)
# Out:
#    Celsius  Fahrenheit
# 0      -50       -58.0
# 1      -40       -40.0
# 2      -30       -22.0
# 3      -20        -4.0
# 4      -10        14.0

# %%
temp_df.tail(10)
# Out:
#     Celsius  Fahrenheit
# 20        6        42.8
# 21        7        44.6
# 22        8        46.4
# 23        9        48.2
# 24       10        50.0
# 25       20        68.0
# 26       30        86.0
# 27       40       104.0
# 28       50       122.0
# 29       60       140.0

# %%
temp_df.describe()
# Out:
#          Celsius  Fahrenheit
# count  30.000000   30.000000
# mean    2.000000   35.600000
# std    22.780815   41.005466
# min   -50.000000  -58.000000
# 25%    -6.750000   19.850000
# 50%     0.500000   32.900000
# 75%     7.750000   45.950000
# max    60.000000  140.000000

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Celsius     30 non-null     int64
#  1   Fahrenheit  30 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 608.0 bytes

# %% [markdown]
# # Visualize dataset

# %%
sns.scatterplot(x='Celsius',y='Fahrenheit',data=temp_df)
# Out:
# <Axes: xlabel='Celsius', ylabel='Fahrenheit'>

# %% [markdown]
# # Create training and testing dataset

# %%
x_train=temp_df['Celsius']
y_train=temp_df['Fahrenheit']

# %% [markdown]
# # build and train the model

# %%
x_train.shape
# Out:
# (30,)

# %%
y_train.shape
# Out:
# (30,)

# %%
import tensorflow as tf
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=1,input_shape=[1]))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(1),loss='mean_squared_error')

# %%
epochs_hist=model.fit(x_train,y_train,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 382ms/step - loss: 7042.2368
# Epoch 2/500
# 1/1 [==============================] - 0s 10ms/step - loss: 3984.3044
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1981.6250
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 982.6219
# Epoch 5/500
# 1/1 [==============================] - 0s 9ms/step - loss: 820.0099
# Epoch 6/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1177.8733
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1661.7623
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1966.6517
# Epoch 9/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1978.2333
# Epoch 10/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1736.4581
# Epoch 11/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1352.1470
# Epoch 12/500
# ...

# %% [markdown]
# #Evaluate the model

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.title('loss vs epochs')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend('Traning Loss')

# %%
model.get_weights()
# Out:
# [array([[1.8000001]], dtype=float32), array([32.], dtype=float32)]

# %%
Temp_C=-32
Temp_F=model.predict([Temp_C])
print('Temperature in DegF',Temp_F)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# Temperature in DegF [[-25.600002]]

# %%
Temp_F=9/5*Temp_C+32
print('Temperature in DegF',Temp_F)
# Out:
# Temperature in DegF -25.6
